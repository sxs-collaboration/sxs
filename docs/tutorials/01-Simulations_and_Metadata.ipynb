# %% [markdown]
# # Simulations and Metadata

# %% [markdown]
# The first things we need to know about the data are
#  1. which simulations are available, and
#  2. what physical systems those simulations represent.
#
# The answers are provided by the `Simulations` object, which contains `Metadata` for each simulation.

# %% [markdown]
# ## Simulations
#
# To begin, we load the `Simulations` object with the `sxs.load` function:

# %%
import sxs

simulations = sxs.load("simulations")

# %% [markdown]
# The first time you call this function, it will attempt to download [the latest data from github](https://github.com/sxs-collaboration/sxs/tree/simulations) and cache it locally, as described in [the previous notebook](../00-Introduction#configuration-and-caching-preliminaries).
#
# The returned object is essentially a `dict`, where the keys are SXS IDs like "SXS:BBH:1234":

# %%
list(simulations)[:10]
# Out:
# ['SXS:BBH:0001',
#  'SXS:BBH:0002',
#  'SXS:BBH:0003',
#  'SXS:BBH:0004',
#  'SXS:BBH:0005',
#  'SXS:BBH:0006',
#  'SXS:BBH:0007',
#  'SXS:BBH:0008',
#  'SXS:BBH:0009',
#  'SXS:BBH:0010']

# %% [markdown]
# The values in this `dict` are essentially also `dict`s with metadata about the simulation.

# %% [markdown]
# ## Metadata
#
# For each simulation, you need to know its physical parameters — mass ratio, spins, initial separation, eccentricity, etc. — as well as information about the simulation itself and where to find the data.  The `sxs.Metadata` object encapsulates that information, with nice interactive features to help you explore.
#
# Just to take an example, let's focus on one particular simulation in the list, the binary black hole simulation with SXS ID `SXS:BBH:0123`:

# %%
metadata = simulations["SXS:BBH:0123"]

# %% [markdown]
# Essentially, `metadata` is a standard python `dict`, with a few extra bells and whistles.  For example, it looks a bit tidier than your basic `dict`:

# %%
metadata
# Out:
# Metadata([('simulation_name',
#            'd15-q1.1-sA_0.266_-0.0234_-0.416_sB_0.027_-0.0595_0.126/Lev5'),
#           ('alternative_names', 'SXS:BBH:0123'),
#           ('initial_data_type', 'BBH_CFMS'),
#           ('object_types', 'BHBH'),
#           ('number_of_orbits', 16.4621796348),
#           ('reference_mass_ratio', 1.1004796188799273),
#           ('reference_chi_eff', -0.15755434271832663),
#           ('reference_chi1_perp', 0.26619415828746285),
#           ('reference_chi2_perp', 0.06460212496073088),
#           ('reference_eccentricity', '<7.2e-05'),
#           ('reference_dimensionless_spin1',
#            [0.266756234962, 0.0203147886466, -0.415103367667]),
#           ('reference_dimensionless_spin2',
#            [0.037600485, -0.053650766128, 0.12634712782]),
#           ('reference_orbital_frequency',
#            [-3.9872660232e-05, -0.00016988370621, 0.0159748747344]),
#           ('reference_mass1', 0.524041316426),
#           ('reference_mass2', 0.476193568182),
#           ('reference_time', 180.0),
#           ('reference_position1',
#            [-6.86617129496, 2.00876691285, -0.0113043076212]),
#           ('reference_position2',
#            [7.48835793679, -2.18522132462, -0.0200766454997]),
#           ('reference_mean_anomaly', 3.124065),
#           ('keywords',
#            ['Precessing-Spins', 'ManyMergers-Random32', 'deprecated']),
#           ('superseded_by', 'SXS:BBH:2394'),
#           ('point_of_contact_email', 'mroue@cita.utoronto.ca'),
#           ('authors_emails',
#            ['Mike Boyle <boyle@astro.cornell.edu>',
#             'Dan Hemberger <daniel.hemberger@gmail.com>',
#             'Larry Kidder  <kidder@astro.cornell.edu>',
#             'Geoffrey Lovelace <glovelace@fullerton.edu>',
#             'Abdul Mroue <mroue@cita.utoronto.ca>',
#             'Harald Pfeiffer <pfeiffer@cita.utoronto.ca>',
#             'Mark Scheel <scheel@tapir.caltech.edu>',
#             'Bela Szilagyi <bela@caltech.edu>',
#             'Nicholas Taylor <nwt2@cornell.edu>',
#             'Anil Zenginoglu <anil@caltech.edu>']),
#           ('simulation_bibtex_keys',
#            ['Mroue:2013xna', 'Boyle:2019kee', 'SXSCatalogWebsite']),
#           ('code_bibtex_keys',
#            ['Ossokine:2013zga',
#             'Hemberger:2012jz',
#             'Szilagyi:2009qz',
#             'Boyle:2009vi',
#             'Scheel:2008rj',
#             'Boyle:2007ft',
#             'Scheel:2006gg',
#             'Lindblom:2005qh',
#             'Pfeiffer:2002wt',
#             'SpECwebsite']),
#           ('initial_data_bibtex_keys',
#            ['Buchman:2012dw',
#             'Lovelace:2008tw',
#             'Pfeiffer:2007yz',
#             'Caudill:2006hw',
#             'Cook:2004kt']),
#           ('quasicircular_bibtex_keys',
#            ['Mroue:2012kv',
#             'Buonanno:2010yk',
#             'Mroue:2010re',
#             'Boyle:2007ft']),
#           ('initial_separation', 15.0),
#           ('initial_orbital_frequency', 0.0158541990364),
#           ('initial_adot', -5.85085341309e-05),
#           ('object1', 'bh'),
#           ('object2', 'bh'),
#           ('initial_ADM_energy', 0.9929656387750304),
#           ('initial_ADM_linear_momentum',
#            [9.51345e-10, 7.240775e-10, -2.40746180934e-05]),
#           ('initial_ADM_angular_momentum',
#            [0.0792457201929709, -0.0190274599776593, 1.0249969870433493]),
#           ('initial_mass1', 0.523809523830852),
#           ('initial_mass2', 0.476190476273648),
#           ('initial_dimensionless_spin1',
#            [0.265999999987, -0.023399999961, -0.41599999998]),
#           ('initial_dimensionless_spin2',
#            [0.0270000000093, -0.0595000000155, 0.126000000029]),
#           ('initial_position1', [7.140836607632183, 0.0059699067005129, 0.0]),
#           ('initial_position2', [-7.859163392367817, 0.0059699067005129, 0.0]),
#           ('relaxation_time', 180.0),
#           ('common_horizon_time', 4365.39365367),
#           ('remnant_mass', 0.955826374012),
#           ('remnant_dimensionless_spin',
#            [0.0485870613722, -0.00260442740925, 0.631965084848]),
#           ('remnant_velocity',
#            [-0.00013415203028, 0.00025113351843, 0.00179443394367]),
#           ('metadata_version', 1),
#           ('spec_revisions', 'InitialCommit-20659-gdb7a1c7'),
#           ('spells_revision', 'InitialCommit-21848-g8d8a7d7'),
#           ('date_postprocessing', '2019-03-30T06:41:50-07:00'),
#           ('date_run_earliest', '2012-08-15T02:45:27'),
#           ('date_run_latest', '2012-08-21T03:25:50'),
#           ('date_link_earliest', '2012-08-07T15:02:51-04:00'),
#           ('initial_mass_ratio', 1.0999999998526622),
#           ('DOI_versions',
#            ['', 'v1.1', 'v1.2', 'v1.3', 'v1.4', 'v1.5', 'v2.0'])])

# %% [markdown]
# Some of these fields are more interesting than others.  Presumably, the most interesting ones are the numbers — things like the mass ratio and spins.  You can access them individually just like any `dict`:

# %%
metadata["reference_mass_ratio"]
# Out:
# 1.1004796188799273

# %% [markdown]
# Note that we also have tab completion when using IPython (or Jupyter).  For example, if you just start with
#
# ```python
# metadata["reference_m
# ```
#
# and then hit tab, you'll see a list of possible completions.  Every key can also be accessed as an attribute:

# %%
metadata.reference_mass_ratio
# Out:
# 1.1004796188799273

# %% [markdown]
# This also gives you tab completion.
#
# Finally, we also provide some backwards compatibility with the older NRAR metadata format, which called for hyphens to be used where we use underscores:

# %%
metadata["reference-mass-ratio"]
# Out:
# 1.1004796188799273

# %% [markdown]
# ## Pain points with the metadata
#
# One of the issues that has built up over time is the fact that metadata keys are not entirely consistent.  For example, one key:value pair we see above is this:

# %%
metadata["reference_eccentricity"]
# Out:
# '<7.2e-05'

# %% [markdown]
# We might have expected to get a number out of this, but we got a string.  This is because the eccentricity fitting function can't always find a very exact value, and only returns an upper bound.  So if you're sorting through lots of different metadata files, looking for eccentricities — let's say — above 0.1, you might have a line that says
#
# ```python
# if metadata["reference_eccentricity"] > 0.1:
#     do_something()
# ```
#
# Unfortunately, once you get to this particular metadata file, that test ***WILL RAISE AN ERROR***:

# %%
metadata["reference_eccentricity"] > 0.1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 metadata["reference_eccentricity"] > 0.1
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %% [markdown]
# There are also many datasets where values are missing.  For example, many of these keys make no sense for simulations with matter (BHNS and NSNS); similarly many critical pieces of information in matter simulations are irrelevant for BBH simulations.
#
# We need a more systematic interface to the data.

# %% [markdown]
# ## Pain reliever: the dataframe
#
# The idea behind these metadata objects is that they should serve as the official records of what was written at the time the simulation was run.  We don't want to be too clever above fixing the pain points, because we might incorrectly change some critical piece of information.
#
# *However*, if you are willing to trade the possibility that this will replace data that you could make sense of with NaNs, for the sake of consistency, then the `simulations` object provides a more uniform interface to all the metadata collected in one place, in the form of `simulations.dataframe`.
#
# The widely used `pandas` package is designed for precisely this application: analysing tabular data with heterogeneously typed columns.  It provides very powerful features for all sorts of sorting, selection, and statistical analysis.  So we use `pandas` to help us:

# %%
df = simulations.dataframe

# %% [markdown]
# This creates a dataframe (or table) with consistent types, and NaN for missing values:

# %%
df
# Out:
#               object_types initial_data_type  initial_separation  \
# SXS:BBH:0001          BHBH          BBH_CFMS            18.00000
# SXS:BBH:0002          BHBH          BBH_CFMS            19.00000
# SXS:BBH:0003          BHBH          BBH_CFMS            19.00000
# SXS:BBH:0004          BHBH          BBH_CFMS            19.00000
# SXS:BBH:0005          BHBH          BBH_CFMS            18.00000
# ...                    ...               ...                 ...
# SXS:BHNS:0008         BHNS              BHNS            62.00490
# SXS:BHNS:0009         BHNS              BHNS            76.09780
# SXS:BHNS:0010         BHNS              BHNS            71.01310
# SXS:NSNS:0001         NSNS              NSNS            39.99990
# SXS:NSNS:0002         NSNS              NSNS            35.50481
#
#                initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BBH:0001                    0.012203     -0.000025            0.993736
# SXS:BBH:0002                    0.011292     -0.000021            0.994031
# SXS:BBH:0003                    0.011284     -0.000019            0.994277
# SXS:BBH:0004                    0.011313     -0.000028            0.994314
# SXS:BBH:0005                    0.012168     -0.000016            0.993947
# ...                                  ...           ...                 ...
# SXS:BHNS:0008                   0.004222      0.000037                 NaN
# SXS:BHNS:0009                   0.003477      0.000028                 NaN
# SXS:BHNS:0010                   0.003524      0.000000                 NaN
# SXS:NSNS:0001                   0.006049     -0.000014            2.778400
# SXS:NSNS:0002                   0.007036      0.000000            2.677702
#
#                                      initial_ADM_linear_momentum  \
# SXS:BBH:0001       [7.5160071e-09, 2.4389069e-09, -5.798632e-10]
# SXS:BBH:0002     [1.6810827e-09, 1.4244131e-09, -1.14839759e-08]
# SXS:BBH:0003   [2.599703e-09, -4.1239227e-09, 6.03918869017e-05]
# SXS:BBH:0004       [-2.7524803e-09, 5.883293e-09, 5.3376578e-09]
# SXS:BBH:0005      [-3.7413651e-09, -2.4006761e-09, 7.874335e-10]
# ...                                                          ...
# SXS:BHNS:0008                                    [nan, nan, nan]
# SXS:BHNS:0009                                    [nan, nan, nan]
# SXS:BHNS:0010                                    [nan, nan, nan]
# SXS:NSNS:0001                                    [nan, nan, nan]
# SXS:NSNS:0002                                    [nan, nan, nan]
#
#                initial_ADM_linear_momentum_mag  \
# SXS:BBH:0001                      7.923059e-09
# SXS:BBH:0002                      1.169345e-08
# SXS:BBH:0003                      6.039189e-05
# SXS:BBH:0004                      8.407132e-09
# SXS:BBH:0005                      4.514544e-09
# ...                                        ...
# SXS:BHNS:0008                              NaN
# SXS:BHNS:0009                              NaN
# SXS:BHNS:0010                              NaN
# SXS:NSNS:0001                              NaN
# SXS:NSNS:0002                              NaN
#
#                                     initial_ADM_angular_momentum  \
# SXS:BBH:0001   [4.27581822e-08, -2.342625073e-07, 1.184715566...
# SXS:BBH:0002   [2.7620419806e-06, -2.4287931932e-06, 1.210130...
# SXS:BBH:0003   [0.1251774015530911, -0.0006755685628109, 1.21...
# SXS:BBH:0004   [8.163645183e-07, 7.736321355e-07, 1.094457487...
# SXS:BBH:0005   [9.790607752e-07, 1.026494432e-07, 1.300909689...
# ...                                                          ...
# SXS:BHNS:0008                                    [nan, nan, nan]
# SXS:BHNS:0009                                    [nan, nan, nan]
# SXS:BHNS:0010                                    [nan, nan, nan]
# SXS:NSNS:0001                                    [nan, nan, nan]
# SXS:NSNS:0002                                    [nan, nan, nan]
#
#                initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BBH:0001                           1.184716  ...        NaN          NaN
# SXS:BBH:0002                           1.210131  ...        NaN          NaN
# SXS:BBH:0003                           1.216661  ...        NaN          NaN
# SXS:BBH:0004                           1.094457  ...        NaN          NaN
# SXS:BBH:0005                           1.300910  ...        NaN          NaN
# ...                                         ...  ...        ...          ...
# SXS:BHNS:0008                               NaN  ...        NaN          NaN
# SXS:BHNS:0009                               NaN  ...        NaN          NaN
# SXS:BHNS:0010                               NaN  ...        NaN          NaN
# SXS:NSNS:0001                               NaN  ...        NaN          NaN
# SXS:NSNS:0002                               NaN  ...        NaN          NaN
#
#                       date_link_earliest        date_postprocessing  \
# SXS:BBH:0001   2012-07-31 13:17:11-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0002   2012-07-31 13:17:11-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0003   2012-08-07 15:02:51-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0004   2012-08-07 15:02:51-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0005   2012-08-07 15:02:51-04:00  2019-03-30 06:41:50-07:00
# ...                                  ...                        ...
# SXS:BHNS:0008  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0009  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0010  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:NSNS:0001  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:NSNS:0002  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                        date_run_earliest            date_run_latest  \
# SXS:BBH:0001   0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0002   0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0003   0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0004   0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0005   0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# ...                                  ...                        ...
# SXS:BHNS:0008  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0009  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0010  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:NSNS:0001  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:NSNS:0002  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                number_of_orbits superseded_by  \
# SXS:BBH:0001          28.119083  SXS:BBH:2325
# SXS:BBH:0002          32.421068  SXS:BBH:2326
# SXS:BBH:0003          32.337574  SXS:BBH:2327
# SXS:BBH:0004          30.188749  SXS:BBH:2328
# SXS:BBH:0005          30.190238  SXS:BBH:2329
# ...                         ...           ...
# SXS:BHNS:0008               NaN           NaN
# SXS:BHNS:0009               NaN           NaN
# SXS:BHNS:0010               NaN           NaN
# SXS:NSNS:0001         12.600000           NaN
# SXS:NSNS:0002          8.200000           NaN
#
#                                                DOI_versions  \
# SXS:BBH:0001   [, v1.1, v1.2, v1.3, v1.4, v1.5, v1.6, v2.0]
# SXS:BBH:0002   [, v1.1, v1.2, v1.4, v1.5, v1.6, v1.7, v2.0]
# SXS:BBH:0003         [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BBH:0004         [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BBH:0005         [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# ...                                                     ...
# SXS:BHNS:0008                                      [, v2.0]
# SXS:BHNS:0009                                      [, v2.0]
# SXS:BHNS:0010                                      [, v2.0]
# SXS:NSNS:0001        [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:NSNS:0002        [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
#
#                                                         keywords
# SXS:BBH:0001   [Non-Spinning, ManyMergers-QuasiCircular, depr...
# SXS:BBH:0002   [Non-Spinning, ManyMergers-QuasiCircular, depr...
# SXS:BBH:0003   [Precessing-Spins, ManyMergers-QuasiCircular, ...
# SXS:BBH:0004   [Aligned-Spins, ManyMergers-QuasiCircular, dep...
# SXS:BBH:0005   [Aligned-Spins, ManyMergers-QuasiCircular, dep...
# ...                                                          ...
# SXS:BHNS:0008                                                 []
# SXS:BHNS:0009                                                 []
# SXS:BHNS:0010                                                 []
# SXS:NSNS:0001                     [NonSpinning, Polytrope, NSNS]
# SXS:NSNS:0002            [NonSpinning, PiecewisePolytrope, NSNS]
#
# [2778 rows x 59 columns]

# %% [markdown]
# Plus, we can use the `qgridnext` package to make this cool interactive table (which, unfortunately, will not show up if you are viewing this as a static web page):

# %%
from qgridnext import show_grid
show_grid(df, precision=8, show_toolbar=True, grid_options={"forceFitColumns": False})
# Out:
# QgridWidget(grid_options={'fullWidthRows': True, 'syncColumnCellResize': True, 'forceFitColumns': False, 'defa…

# %% [markdown]
# You can sort by a column by clicking on the column header.  You can also filter by value by clicking the <span class="fa fa-filter filter-icon"></span> icon in the header.

# %% [markdown]
# ## Doing that and more, programatically
#
# While graphical interfaces are fun, there is more reproducibility and power in programming.

# %% [markdown]
# ### Slices
#
# We can slice the dataframe in a dizzying number of ways.  But there are two that are simplest and most reliable.  First, and most easily, we can take standard slices, like the first four elements:

# %%
df[:4]
# Out:
#              object_types initial_data_type  initial_separation  \
# SXS:BBH:0001         BHBH          BBH_CFMS                18.0
# SXS:BBH:0002         BHBH          BBH_CFMS                19.0
# SXS:BBH:0003         BHBH          BBH_CFMS                19.0
# SXS:BBH:0004         BHBH          BBH_CFMS                19.0
#
#               initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BBH:0001                   0.012203     -0.000025            0.993736
# SXS:BBH:0002                   0.011292     -0.000021            0.994031
# SXS:BBH:0003                   0.011284     -0.000019            0.994277
# SXS:BBH:0004                   0.011313     -0.000028            0.994314
#
#                                     initial_ADM_linear_momentum  \
# SXS:BBH:0001      [7.5160071e-09, 2.4389069e-09, -5.798632e-10]
# SXS:BBH:0002    [1.6810827e-09, 1.4244131e-09, -1.14839759e-08]
# SXS:BBH:0003  [2.599703e-09, -4.1239227e-09, 6.03918869017e-05]
# SXS:BBH:0004      [-2.7524803e-09, 5.883293e-09, 5.3376578e-09]
#
#               initial_ADM_linear_momentum_mag  \
# SXS:BBH:0001                     7.923059e-09
# SXS:BBH:0002                     1.169345e-08
# SXS:BBH:0003                     6.039189e-05
# SXS:BBH:0004                     8.407132e-09
#
#                                    initial_ADM_angular_momentum  \
# SXS:BBH:0001  [4.27581822e-08, -2.342625073e-07, 1.184715566...
# SXS:BBH:0002  [2.7620419806e-06, -2.4287931932e-06, 1.210130...
# SXS:BBH:0003  [0.1251774015530911, -0.0006755685628109, 1.21...
# SXS:BBH:0004  [8.163645183e-07, 7.736321355e-07, 1.094457487...
#
#               initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BBH:0001                          1.184716  ...        NaN          NaN
# SXS:BBH:0002                          1.210131  ...        NaN          NaN
# SXS:BBH:0003                          1.216661  ...        NaN          NaN
# SXS:BBH:0004                          1.094457  ...        NaN          NaN
#
#                      date_link_earliest        date_postprocessing  \
# SXS:BBH:0001  2012-07-31 13:17:11-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0002  2012-07-31 13:17:11-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0003  2012-08-07 15:02:51-04:00  2019-03-30 06:41:50-07:00
# SXS:BBH:0004  2012-08-07 15:02:51-04:00  2019-03-30 06:41:50-07:00
#
#                       date_run_earliest            date_run_latest  \
# SXS:BBH:0001  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0002  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0003  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0004  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#               number_of_orbits superseded_by  \
# SXS:BBH:0001         28.119083  SXS:BBH:2325
# SXS:BBH:0002         32.421068  SXS:BBH:2326
# SXS:BBH:0003         32.337574  SXS:BBH:2327
# SXS:BBH:0004         30.188749  SXS:BBH:2328
#
#                                               DOI_versions  \
# SXS:BBH:0001  [, v1.1, v1.2, v1.3, v1.4, v1.5, v1.6, v2.0]
# SXS:BBH:0002  [, v1.1, v1.2, v1.4, v1.5, v1.6, v1.7, v2.0]
# SXS:BBH:0003        [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BBH:0004        [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
#
#                                                        keywords
# SXS:BBH:0001  [Non-Spinning, ManyMergers-QuasiCircular, depr...
# SXS:BBH:0002  [Non-Spinning, ManyMergers-QuasiCircular, depr...
# SXS:BBH:0003  [Precessing-Spins, ManyMergers-QuasiCircular, ...
# SXS:BBH:0004  [Aligned-Spins, ManyMergers-QuasiCircular, dep...
#
# [4 rows x 59 columns]

# %% [markdown]
# Or we can select columns to extract:

# %%
df[["object_types", "initial_adot"]]
# Out:
#               object_types  initial_adot
# SXS:BBH:0001          BHBH     -0.000025
# SXS:BBH:0002          BHBH     -0.000021
# SXS:BBH:0003          BHBH     -0.000019
# SXS:BBH:0004          BHBH     -0.000028
# SXS:BBH:0005          BHBH     -0.000016
# ...                    ...           ...
# SXS:BHNS:0008         BHNS      0.000037
# SXS:BHNS:0009         BHNS      0.000028
# SXS:BHNS:0010         BHNS      0.000000
# SXS:NSNS:0001         NSNS     -0.000014
# SXS:NSNS:0002         NSNS      0.000000
#
# [2778 rows x 2 columns]

# %% [markdown]
# To combine them, we just do them in sequence:

# %%
df[:4][["object_types", "initial_adot"]]
# Out:
#              object_types  initial_adot
# SXS:BBH:0001         BHBH     -0.000025
# SXS:BBH:0002         BHBH     -0.000021
# SXS:BBH:0003         BHBH     -0.000019
# SXS:BBH:0004         BHBH     -0.000028

# %% [markdown]
# ### Tests
#
# The concept of tests is fairly simply.  For example, we can test whether or not the `object_types` field is equal to `BHNS`:

# %%
df["object_types"] == "BHNS"
# Out:
# SXS:BBH:0001     False
# SXS:BBH:0002     False
# SXS:BBH:0003     False
# SXS:BBH:0004     False
# SXS:BBH:0005     False
#                  ...
# SXS:BHNS:0008     True
# SXS:BHNS:0009     True
# SXS:BHNS:0010     True
# SXS:NSNS:0001    False
# SXS:NSNS:0002    False
# Name: object_types, Length: 2778, dtype: bool

# %% [markdown]
# We get a pandas Series object, where most of the results say `False`, but the last few say `True` — because they are the ones for which the `object_types` field is `BHNS`.  Now, we can use this Series just like we would in numpy to extract the items where this test gives us `True`:

# %%
df[df["object_types"] == "BHNS"]
# Out:
#               object_types initial_data_type  initial_separation  \
# SXS:BHNS:0001         BHNS              BHNS            106.6800
# SXS:BHNS:0002         BHNS              BHNS             56.0000
# SXS:BHNS:0003         BHNS              BHNS             51.4300
# SXS:BHNS:0004         BHNS              BHNS             39.2000
# SXS:BHNS:0005         BHNS              BHNS             39.2000
# SXS:BHNS:0006         BHNS              BHNS             52.5000
# SXS:BHNS:0007         BHNS              BHNS             56.0000
# SXS:BHNS:0008         BHNS              BHNS             62.0049
# SXS:BHNS:0009         BHNS              BHNS             76.0978
# SXS:BHNS:0010         BHNS              BHNS             71.0131
#
#                initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BHNS:0001                   0.002537      0.000001            9.754357
# SXS:BHNS:0002                   0.004456     -0.000015            4.169582
# SXS:BHNS:0003                   0.005595      0.000000            5.400000
# SXS:BHNS:0004                   0.006233     -0.000022            2.778112
# SXS:BHNS:0005                   0.006235     -0.000025            2.780039
# SXS:BHNS:0006                   0.004524     -0.000012            3.475229
# SXS:BHNS:0007                   0.004454     -0.000015            4.171456
# SXS:BHNS:0008                   0.004222      0.000037                 NaN
# SXS:BHNS:0009                   0.003477      0.000028                 NaN
# SXS:BHNS:0010                   0.003524      0.000000                 NaN
#
#                                      initial_ADM_linear_momentum  \
# SXS:BHNS:0001  [-2.03885932771e-05, 9.797238987913e-05, -5.05...
# SXS:BHNS:0002  [-1.9413609314e-06, -8.496132757e-07, 1.095574...
# SXS:BHNS:0003                                    [0.0, 0.0, 0.0]
# SXS:BHNS:0004  [-1.2457454507e-06, 5.44427247228e-06, -6.2716...
# SXS:BHNS:0005  [2.981054730059816e-06, -1.22406716840395e-06,...
# SXS:BHNS:0006  [-3.413420373258928e-06, -2.0768413414982537e-...
# SXS:BHNS:0007  [4.867002495810236e-07, -1.5158476150901928e-0...
# SXS:BHNS:0008                                    [nan, nan, nan]
# SXS:BHNS:0009                                    [nan, nan, nan]
# SXS:BHNS:0010                                    [nan, nan, nan]
#
#                initial_ADM_linear_momentum_mag  \
# SXS:BHNS:0001                         0.000100
# SXS:BHNS:0002                         0.000002
# SXS:BHNS:0003                         0.000000
# SXS:BHNS:0004                         0.000006
# SXS:BHNS:0005                         0.000003
# SXS:BHNS:0006                         0.000004
# SXS:BHNS:0007                         0.000015
# SXS:BHNS:0008                              NaN
# SXS:BHNS:0009                              NaN
# SXS:BHNS:0010                              NaN
#
#                           initial_ADM_angular_momentum  \
# SXS:BHNS:0001  [1.71682e-10, -4.67012e-09, 46.6686927]
# SXS:BHNS:0002            [0.0, 0.0, 16.60638426824671]
# SXS:BHNS:0003            [0.0, 0.0, 16.60638426824671]
# SXS:BHNS:0004            [0.0, 0.0, 8.447059816549256]
# SXS:BHNS:0005            [0.0, 0.0, 8.111755992167552]
# SXS:BHNS:0006           [0.0, 0.0, 12.993342233650518]
# SXS:BHNS:0007            [0.0, 0.0, 16.29283505660932]
# SXS:BHNS:0008                          [nan, nan, nan]
# SXS:BHNS:0009                          [nan, nan, nan]
# SXS:BHNS:0010                          [nan, nan, nan]
#
#                initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BHNS:0001                         46.668693  ...   0.000000          0.0
# SXS:BHNS:0002                         16.606384  ...   0.049606          NaN
# SXS:BHNS:0003                         16.606384  ...        NaN          NaN
# SXS:BHNS:0004                          8.447060  ...        NaN          NaN
# SXS:BHNS:0005                          8.111756  ...        NaN          NaN
# SXS:BHNS:0006                         12.993342  ...        NaN          NaN
# SXS:BHNS:0007                         16.292835  ...        NaN          NaN
# SXS:BHNS:0008                               NaN  ...        NaN          NaN
# SXS:BHNS:0009                               NaN  ...        NaN          NaN
# SXS:BHNS:0010                               NaN  ...        NaN          NaN
#
#                       date_link_earliest        date_postprocessing  \
# SXS:BHNS:0001  2013-03-06 13:52:11-08:00  2019-04-14 19:48:30-07:00
# SXS:BHNS:0002  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0003  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0004  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0005  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0006  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0007  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0008  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0009  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0010  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                        date_run_earliest            date_run_latest  \
# SXS:BHNS:0001  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0002  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0003  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0004  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0005  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0006  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0007  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0008  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0009  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0010  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                number_of_orbits superseded_by  \
# SXS:BHNS:0001         12.647523           NaN
# SXS:BHNS:0002         13.300000           NaN
# SXS:BHNS:0003         13.300000           NaN
# SXS:BHNS:0004         12.300000           NaN
# SXS:BHNS:0005         10.800000           NaN
# SXS:BHNS:0006         16.600000           NaN
# SXS:BHNS:0007         12.300000           NaN
# SXS:BHNS:0008               NaN           NaN
# SXS:BHNS:0009               NaN           NaN
# SXS:BHNS:0010               NaN           NaN
#
#                                          DOI_versions  \
# SXS:BHNS:0001        [, v1.1, v1.2, v1.3, v1.4, v2.0]
# SXS:BHNS:0002        [, v1.1, v1.2, v1.3, v1.4, v2.0]
# SXS:BHNS:0003        [, v1.1, v1.2, v1.3, v1.4, v2.0]
# SXS:BHNS:0004  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BHNS:0005  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BHNS:0006  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BHNS:0007  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BHNS:0008                                [, v2.0]
# SXS:BHNS:0009                                [, v2.0]
# SXS:BHNS:0010                                [, v2.0]
#
#                                 keywords
# SXS:BHNS:0001  [Non-Spinning, Polytrope]
# SXS:BHNS:0002  [Non-Spinning, Polytrope]
# SXS:BHNS:0003  [Non-Spinning, Polytrope]
# SXS:BHNS:0004   [NonSpinning, Polytrope]
# SXS:BHNS:0005    [SpinningNS, Polytrope]
# SXS:BHNS:0006   [NonSpinning, Polytrope]
# SXS:BHNS:0007    [SpinningNS, Polytrope]
# SXS:BHNS:0008                         []
# SXS:BHNS:0009                         []
# SXS:BHNS:0010                         []
#
# [10 rows x 59 columns]

# %% [markdown]
# (Here, we're just looking at the data, so we don't bother with the fancy grid we used above.)

# %% [markdown]
# Next, we might want to combine tests.  This is done by putting each test inside parentheses, and combinging results with `&`:

# %%
df[(df["object_types"] == "BHNS") & (df["initial_separation"] < 52)]
# Out:
#               object_types initial_data_type  initial_separation  \
# SXS:BHNS:0003         BHNS              BHNS               51.43
# SXS:BHNS:0004         BHNS              BHNS               39.20
# SXS:BHNS:0005         BHNS              BHNS               39.20
#
#                initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BHNS:0003                   0.005595      0.000000            5.400000
# SXS:BHNS:0004                   0.006233     -0.000022            2.778112
# SXS:BHNS:0005                   0.006235     -0.000025            2.780039
#
#                                      initial_ADM_linear_momentum  \
# SXS:BHNS:0003                                    [0.0, 0.0, 0.0]
# SXS:BHNS:0004  [-1.2457454507e-06, 5.44427247228e-06, -6.2716...
# SXS:BHNS:0005  [2.981054730059816e-06, -1.22406716840395e-06,...
#
#                initial_ADM_linear_momentum_mag   initial_ADM_angular_momentum  \
# SXS:BHNS:0003                         0.000000  [0.0, 0.0, 16.60638426824671]
# SXS:BHNS:0004                         0.000006  [0.0, 0.0, 8.447059816549256]
# SXS:BHNS:0005                         0.000003  [0.0, 0.0, 8.111755992167552]
#
#                initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BHNS:0003                         16.606384  ...        NaN          NaN
# SXS:BHNS:0004                          8.447060  ...        NaN          NaN
# SXS:BHNS:0005                          8.111756  ...        NaN          NaN
#
#                       date_link_earliest        date_postprocessing  \
# SXS:BHNS:0003  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0004  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0005  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                        date_run_earliest            date_run_latest  \
# SXS:BHNS:0003  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0004  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BHNS:0005  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#                number_of_orbits superseded_by  \
# SXS:BHNS:0003              13.3           NaN
# SXS:BHNS:0004              12.3           NaN
# SXS:BHNS:0005              10.8           NaN
#
#                                          DOI_versions  \
# SXS:BHNS:0003        [, v1.1, v1.2, v1.3, v1.4, v2.0]
# SXS:BHNS:0004  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
# SXS:BHNS:0005  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]
#
#                                 keywords
# SXS:BHNS:0003  [Non-Spinning, Polytrope]
# SXS:BHNS:0004   [NonSpinning, Polytrope]
# SXS:BHNS:0005    [SpinningNS, Polytrope]
#
# [3 rows x 59 columns]

# %% [markdown]
# Here, the combined test is only `True` if both tests to return `True` — the `&` operator is the boolean AND.  We also have OR with `|` and XOR with `^`, as well as negation with `~` — though this can usually be achieved by changing the test.

# %% [markdown]
# Before we do anything else, it's convenient to use what we've just learned to separate out the different types of systems:

# %%
BHBH = df[df["object_types"] == "BHBH"]
BHNS = df[df["object_types"] == "BHNS"]
NSNS = df[df["object_types"] == "NSNS"]

# %% [markdown]
# ### Sorting
#
# As with the fancy graphical table above, we can perform a standard sort with respect to any key:

# %%
BHBH.sort_values("initial_separation")
# Out:
#              object_types initial_data_type  initial_separation  \
# SXS:BBH:1145         BHBH           BBH_SKS            8.768433
# SXS:BBH:3722         BHBH           BBH_SKS            9.407000
# SXS:BBH:3704         BHBH           BBH_SKS            9.430725
# SXS:BBH:3726         BHBH           BBH_SKS            9.462000
# SXS:BBH:3720         BHBH           BBH_SKS            9.488000
# ...                   ...               ...                 ...
# SXS:BBH:3887         BHBH           BBH_SHK           50.000000
# SXS:BBH:3888         BHBH           BBH_SHK           50.000000
# SXS:BBH:3890         BHBH           BBH_SHK           50.000000
# SXS:BBH:3880         BHBH           BBH_SHK           50.000000
# SXS:BBH:3889         BHBH           BBH_SHK           50.000000
#
#               initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BBH:1145                   0.033400      0.000528            0.988193
# SXS:BBH:3722                   0.030000     -0.000198            0.993240
# SXS:BBH:3704                   0.030108     -0.000031            0.989613
# SXS:BBH:3726                   0.030000     -0.000289            0.990572
# SXS:BBH:3720                   0.030000     -0.000294            0.989701
# ...                                 ...           ...                 ...
# SXS:BBH:3887                   0.001265     -0.003795            1.000471
# SXS:BBH:3888                   0.001265     -0.003795            1.000461
# SXS:BBH:3890                   0.001386     -0.003752            1.000460
# SXS:BBH:3880                   0.000566     -0.003960            1.000462
# SXS:BBH:3889                   0.001386     -0.003752            1.000470
#
#                                     initial_ADM_linear_momentum  \
# SXS:BBH:1145    [4.0159705e-09, -2.8874734e-09, 2.20182446e-08]
# SXS:BBH:3722      [7.9609465e-09, 5.0432421e-09, 3.9775058e-09]
# SXS:BBH:3704    [1.658214632e-07, 9.05567461e-08, 1.195347e-10]
# SXS:BBH:3726    [-3.86638787e-08, -3.8823479e-08, -7.78173e-11]
# SXS:BBH:3720     [1.06827404e-08, 1.30354321e-08, 5.719484e-10]
# ...                                                         ...
# SXS:BBH:3887   [8.94575691e-08, -4.9269905e-08, 2.79076348e-08]
# SXS:BBH:3888  [-2.335461483e-07, 7.29418664e-08, -1.067907e-10]
# SXS:BBH:3890  [-2.719040168e-07, 1.136213141e-07, -3.4949572...
# SXS:BBH:3880  [-1.984851206e-07, 7.14894112e-08, 1.83540698e...
# SXS:BBH:3889   [-6.41120096e-08, 3.31272244e-08, 7.8116942e-09]
#
#               initial_ADM_linear_momentum_mag  \
# SXS:BBH:1145                     2.256698e-08
# SXS:BBH:3722                     1.022895e-08
# SXS:BBH:3704                     1.889373e-07
# SXS:BBH:3726                     5.479201e-08
# SXS:BBH:3720                     1.686329e-08
# ...                                       ...
# SXS:BBH:3887                     1.058726e-07
# SXS:BBH:3888                     2.446719e-07
# SXS:BBH:3890                     2.947097e-07
# SXS:BBH:3880                     2.117639e-07
# SXS:BBH:3889                     7.258640e-08
#
#                                    initial_ADM_angular_momentum  \
# SXS:BBH:1145   [-5.79788e-11, -4.11334e-11, 0.8979940168937853]
# SXS:BBH:3722  [0.5037166261156991, -0.2145529574370644, 0.84...
# SXS:BBH:3704  [0.0039265586291782, -6.43212220851e-05, 1.040...
# SXS:BBH:3726  [-0.315268326520386, 0.0440983611469425, 1.076...
# SXS:BBH:3720  [-0.1321012340474509, 0.1426761200702829, 1.06...
# ...                                                         ...
# SXS:BBH:3887  [-8.318914e-10, -8.2845346e-09, 0.848886312699...
# SXS:BBH:3888  [-5.725183e-10, -1.29348339e-08, 0.81525856904...
# SXS:BBH:3890  [2.8414687e-09, 3.1733529e-09, 0.8930582982295...
# SXS:BBH:3880  [5.0134435e-09, -6.034878e-10, 0.3646142878691...
# SXS:BBH:3889  [-2.2777349e-09, 5.7852127e-09, 0.929894586374...
#
#               initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BBH:1145                          0.897994  ...        NaN          NaN
# SXS:BBH:3722                          1.009884  ...        NaN          NaN
# SXS:BBH:3704                          1.040374  ...        NaN          NaN
# SXS:BBH:3726                          1.122706  ...        NaN          NaN
# SXS:BBH:3720                          1.081416  ...        NaN          NaN
# ...                                        ...  ...        ...          ...
# SXS:BBH:3887                          0.848886  ...        NaN          NaN
# SXS:BBH:3888                          0.815259  ...        NaN          NaN
# SXS:BBH:3890                          0.893058  ...        NaN          NaN
# SXS:BBH:3880                          0.364614  ...        NaN          NaN
# SXS:BBH:3889                          0.929895  ...        NaN          NaN
#
#                      date_link_earliest        date_postprocessing  \
# SXS:BBH:1145  2015-09-23 08:06:10-07:00  2019-04-23 08:53:25-07:00
# SXS:BBH:3722  2022-01-15 13:49:17-08:00  2022-08-08 18:18:46-05:00
# SXS:BBH:3704  2020-06-17 22:27:31-07:00  2020-08-09 12:14:41-07:00
# SXS:BBH:3726  2021-07-21 12:36:21-07:00  2022-05-23 15:20:27-05:00
# SXS:BBH:3720  2022-01-15 13:49:17-08:00  2022-04-01 12:39:03-05:00
# ...                                 ...                        ...
# SXS:BBH:3887  2019-11-05 10:57:50+01:00  2023-11-27 14:58:52+00:00
# SXS:BBH:3888  2019-11-05 10:57:50+01:00  2023-11-27 15:07:14+00:00
# SXS:BBH:3890  2019-11-05 10:57:50+01:00  2023-11-27 14:50:29+00:00
# SXS:BBH:3880  2019-11-05 10:57:50+01:00  2023-10-25 16:01:41+01:00
# SXS:BBH:3889  2019-11-05 10:57:50+01:00  0001-01-01 00:00:00+00:00
#
#                       date_run_earliest            date_run_latest  \
# SXS:BBH:1145  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3722  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3704  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3726  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3720  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# ...                                 ...                        ...
# SXS:BBH:3887  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3888  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3890  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3880  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3889  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#               number_of_orbits superseded_by  \
# SXS:BBH:1145          3.495636           NaN
# SXS:BBH:3722          9.975052           NaN
# SXS:BBH:3704          6.396565           NaN
# SXS:BBH:3726          8.439591           NaN
# SXS:BBH:3720          6.843151           NaN
# ...                        ...           ...
# SXS:BBH:3887          0.583553           NaN
# SXS:BBH:3888          0.582871           NaN
# SXS:BBH:3890          1.079663           NaN
# SXS:BBH:3880          0.128044           NaN
# SXS:BBH:3889          1.114827           NaN
#
#                                   DOI_versions      keywords
# SXS:BBH:1145  [, v1.2, v1.3, v1.4, v1.5, v2.0]            []
# SXS:BBH:3722                          [, v2.0]            []
# SXS:BBH:3704                          [, v2.0]            []
# SXS:BBH:3726                          [, v2.0]            []
# SXS:BBH:3720                          [, v2.0]            []
# ...                                        ...           ...
# SXS:BBH:3887                          [, v2.0]  AlmostHeadOn
# SXS:BBH:3888                          [, v2.0]  AlmostHeadOn
# SXS:BBH:3890                          [, v2.0]  AlmostHeadOn
# SXS:BBH:3880                          [, v2.0]  AlmostHeadOn
# SXS:BBH:3889                          [, v2.0]  AlmostHeadOn
#
# [2766 rows x 59 columns]

# %% [markdown]
# But unlike the fancy graphical table above, we can use a function that serves as the sort key.  (This sort of key function is also available in the standard python library's `sorted` function.)  Here, we'll sort by the absolute value of the difference between `initial_separation` and 20.0.

# %%
sorting_field = "initial_separation"
desired_value = 20.0

BHBH.sort_values(sorting_field, key=lambda s: abs(s-desired_value))
# Out:
#              object_types initial_data_type  initial_separation  \
# SXS:BBH:0204         BHBH          BBH_CFMS           20.000000
# SXS:BBH:1131         BHBH           BBH_SKS           20.000000
# SXS:BBH:1130         BHBH           BBH_SKS           20.000000
# SXS:BBH:0623         BHBH           BBH_SKS           20.000000
# SXS:BBH:3661         BHBH           BBH_SKS           19.998596
# ...                   ...               ...                 ...
# SXS:BBH:3886         BHBH           BBH_SHK           50.000000
# SXS:BBH:3887         BHBH           BBH_SHK           50.000000
# SXS:BBH:3888         BHBH           BBH_SHK           50.000000
# SXS:BBH:3876         BHBH           BBH_SHK           50.000000
# SXS:BBH:3875         BHBH           BBH_SHK           50.000000
#
#               initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BBH:0204               1.044600e-02     -0.000005            0.997651
# SXS:BBH:1131               1.040251e-02      0.000003            0.994285
# SXS:BBH:1130               1.052571e-02      0.000001            0.994279
# SXS:BBH:0623               9.836914e-03      0.000055            0.994419
# SXS:BBH:3661               1.038109e-02      0.000038            0.994403
# ...                                 ...           ...                 ...
# SXS:BBH:3886               1.131371e-03     -0.003837            1.000460
# SXS:BBH:3887               1.264911e-03     -0.003795            1.000471
# SXS:BBH:3888               1.264911e-03     -0.003795            1.000461
# SXS:BBH:3876               5.671010e-07     -0.004031            1.000546
# SXS:BBH:3875               5.642800e-07     -0.004020            1.000530
#
#                                     initial_ADM_linear_momentum  \
# SXS:BBH:0204   [-4.10550747e-08, 2.06116119e-08, 9.9919665e-09]
# SXS:BBH:1131    [1.47849e-11, -1.80773e-11, 0.0005509351422452]
# SXS:BBH:1130  [-1.240433e-10, 1.000485e-10, -0.0002327491542...
# SXS:BBH:0623  [-1.2597544e-09, 2.584556e-10, -3.42284249539e...
# SXS:BBH:3661      [2.0983064e-09, -7.882067e-10, -2.033826e-10]
# ...                                                         ...
# SXS:BBH:3886  [-1.240946089e-07, 6.57098189e-08, 3.44856742e...
# SXS:BBH:3887   [8.94575691e-08, -4.9269905e-08, 2.79076348e-08]
# SXS:BBH:3888  [-2.335461483e-07, 7.29418664e-08, -1.067907e-10]
# SXS:BBH:3876    [-3.8975884e-09, 6.1414968e-09, -1.9501199e-09]
# SXS:BBH:3875    [9.86804702e-08, -2.08462494e-08, 7.611129e-10]
#
#               initial_ADM_linear_momentum_mag  \
# SXS:BBH:0204                     4.701273e-08
# SXS:BBH:1131                     5.509351e-04
# SXS:BBH:1130                     2.327492e-04
# SXS:BBH:0623                     3.422842e-05
# SXS:BBH:3661                     2.250672e-09
# ...                                       ...
# SXS:BBH:3886                     1.445909e-07
# SXS:BBH:3887                     1.058726e-07
# SXS:BBH:3888                     2.446719e-07
# SXS:BBH:3876                     7.530747e-09
# SXS:BBH:3875                     1.008612e-07
#
#                                    initial_ADM_angular_momentum  \
# SXS:BBH:0204  [5.532205836e-06, 4.47633244527e-05, 0.8415017...
# SXS:BBH:1131  [0.1509150594264362, -0.0062555203815311, 1.23...
# SXS:BBH:1130  [8.52611666819e-05, 0.1452893471026843, 1.2337...
# SXS:BBH:0623  [0.4507311241093057, -0.0400147208043062, 1.23...
# SXS:BBH:3661  [1.334879298e-07, 7.18252001e-07, 1.3819318838...
# ...                                                         ...
# SXS:BBH:3886  [5.2596452e-09, -6.9540665e-09, 0.729198451607...
# SXS:BBH:3887  [-8.318914e-10, -8.2845346e-09, 0.848886312699...
# SXS:BBH:3888  [-5.725183e-10, -1.29348339e-08, 0.81525856904...
# SXS:BBH:3876  [-4.3764712e-09, 2.5430775e-09, 0.000365571428...
# SXS:BBH:3875  [3.8300267e-09, 3.118198e-10, 0.0003787432241755]
#
#               initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BBH:0204                          0.841502  ...        NaN          NaN
# SXS:BBH:1131                          1.242480  ...        NaN          NaN
# SXS:BBH:1130                          1.242241  ...        NaN          NaN
# SXS:BBH:0623                          1.311154  ...        NaN          NaN
# SXS:BBH:3661                          1.381932  ...        NaN          NaN
# ...                                        ...  ...        ...          ...
# SXS:BBH:3886                          0.729198  ...        NaN          NaN
# SXS:BBH:3887                          0.848886  ...        NaN          NaN
# SXS:BBH:3888                          0.815259  ...        NaN          NaN
# SXS:BBH:3876                          0.000366  ...        NaN          NaN
# SXS:BBH:3875                          0.000379  ...        NaN          NaN
#
#                      date_link_earliest        date_postprocessing  \
# SXS:BBH:0204  2013-08-23 15:48:09-07:00  2019-04-14 19:48:30-07:00
# SXS:BBH:1131  2014-06-30 10:56:22-07:00  2019-04-20 18:22:40-07:00
# SXS:BBH:1130  2014-07-16 11:32:05-07:00  2019-04-20 18:22:40-07:00
# SXS:BBH:0623  2015-01-08 16:07:43-08:00  2019-04-20 18:22:40-07:00
# SXS:BBH:3661  2015-04-06 15:49:13-05:00  2019-04-18 10:17:19-07:00
# ...                                 ...                        ...
# SXS:BBH:3886  2019-11-05 10:57:50+01:00  2023-12-04 18:11:08+00:00
# SXS:BBH:3887  2019-11-05 10:57:50+01:00  2023-11-27 14:58:52+00:00
# SXS:BBH:3888  2019-11-05 10:57:50+01:00  2023-11-27 15:07:14+00:00
# SXS:BBH:3876  2019-11-05 10:57:50+01:00  2023-10-24 15:57:23+01:00
# SXS:BBH:3875  2019-11-05 10:57:50+01:00  2023-10-24 15:57:23+01:00
#
#                       date_run_earliest            date_run_latest  \
# SXS:BBH:0204  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:1131  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:1130  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0623  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3661  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# ...                                 ...                        ...
# SXS:BBH:3886  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3887  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3888  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3876  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3875  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#               number_of_orbits superseded_by  \
# SXS:BBH:0204         88.369299           NaN
# SXS:BBH:1131         36.796011           NaN
# SXS:BBH:1130         36.775214           NaN
# SXS:BBH:0623         37.470458           NaN
# SXS:BBH:3661         41.006968           NaN
# ...                        ...           ...
# SXS:BBH:3886          0.393473           NaN
# SXS:BBH:3887          0.583553           NaN
# SXS:BBH:3888          0.582871           NaN
# SXS:BBH:3876          0.000116           NaN
# SXS:BBH:3875          0.000116           NaN
#
#                                         DOI_versions      keywords
# SXS:BBH:0204  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]            []
# SXS:BBH:1131        [, v1.2, v1.3, v1.4, v1.5, v2.0]            []
# SXS:BBH:1130        [, v1.2, v1.3, v1.4, v1.5, v2.0]            []
# SXS:BBH:0623        [, v1.2, v1.3, v1.4, v1.5, v2.0]            []
# SXS:BBH:3661                                [, v2.0]            []
# ...                                              ...           ...
# SXS:BBH:3886                                [, v2.0]  AlmostHeadOn
# SXS:BBH:3887                                [, v2.0]  AlmostHeadOn
# SXS:BBH:3888                                [, v2.0]  AlmostHeadOn
# SXS:BBH:3876                                [, v2.0]  AlmostHeadOn
# SXS:BBH:3875                                [, v2.0]  AlmostHeadOn
#
# [2766 rows x 59 columns]

# %% [markdown]
# So, if we want the 8 systems with initial separations closest to 20, we can just take them:

# %%
sorting_field = "initial_separation"
desired_value = 20.0
N = 8

BHBH.sort_values(sorting_field, key=lambda s: abs(s-desired_value))[:N]
# Out:
#              object_types initial_data_type  initial_separation  \
# SXS:BBH:0204         BHBH          BBH_CFMS           20.000000
# SXS:BBH:1131         BHBH           BBH_SKS           20.000000
# SXS:BBH:1130         BHBH           BBH_SKS           20.000000
# SXS:BBH:0623         BHBH           BBH_SKS           20.000000
# SXS:BBH:3661         BHBH           BBH_SKS           19.998596
# SXS:BBH:2299         BHBH           BBH_SHK           19.997802
# SXS:BBH:2603         BHBH           BBH_SHK           19.997802
# SXS:BBH:3913         BHBH           BBH_SKS           20.014343
#
#               initial_orbital_frequency  initial_adot  initial_ADM_energy  \
# SXS:BBH:0204                   0.010446     -0.000005            0.997651
# SXS:BBH:1131                   0.010403      0.000003            0.994285
# SXS:BBH:1130                   0.010526      0.000001            0.994279
# SXS:BBH:0623                   0.009837      0.000055            0.994419
# SXS:BBH:3661                   0.010381      0.000038            0.994403
# SXS:BBH:2299                   0.010194      0.002171            0.994103
# SXS:BBH:2603                   0.010194      0.002171            0.994103
# SXS:BBH:3913                   0.010177      0.000130            0.994365
#
#                                     initial_ADM_linear_momentum  \
# SXS:BBH:0204   [-4.10550747e-08, 2.06116119e-08, 9.9919665e-09]
# SXS:BBH:1131    [1.47849e-11, -1.80773e-11, 0.0005509351422452]
# SXS:BBH:1130  [-1.240433e-10, 1.000485e-10, -0.0002327491542...
# SXS:BBH:0623  [-1.2597544e-09, 2.584556e-10, -3.42284249539e...
# SXS:BBH:3661      [2.0983064e-09, -7.882067e-10, -2.033826e-10]
# SXS:BBH:2299        [9.977159e-09, 1.1158121e-08, 2.210107e-10]
# SXS:BBH:2603     [1.25331308e-08, 1.67409341e-08, -3.89072e-11]
# SXS:BBH:3913       [-8.8487893e-08, 9.17480655e-08, 5.0764e-12]
#
#               initial_ADM_linear_momentum_mag  \
# SXS:BBH:0204                     4.701273e-08
# SXS:BBH:1131                     5.509351e-04
# SXS:BBH:1130                     2.327492e-04
# SXS:BBH:0623                     3.422842e-05
# SXS:BBH:3661                     2.250672e-09
# SXS:BBH:2299                     1.496984e-08
# SXS:BBH:2603                     2.091267e-08
# SXS:BBH:3913                     1.274669e-07
#
#                                    initial_ADM_angular_momentum  \
# SXS:BBH:0204  [5.532205836e-06, 4.47633244527e-05, 0.8415017...
# SXS:BBH:1131  [0.1509150594264362, -0.0062555203815311, 1.23...
# SXS:BBH:1130  [8.52611666819e-05, 0.1452893471026843, 1.2337...
# SXS:BBH:0623  [0.4507311241093057, -0.0400147208043062, 1.23...
# SXS:BBH:3661  [1.334879298e-07, 7.18252001e-07, 1.3819318838...
# SXS:BBH:2299    [-9.49201e-11, -6.10328e-11, 1.190023790296173]
# SXS:BBH:2603    [2.457399e-10, 2.748791e-10, 1.190023742793307]
# SXS:BBH:3913       [-1.9339e-12, 3.7192e-12, 1.360752542245232]
#
#               initial_ADM_angular_momentum_mag  ...  disk_mass  ejecta_mass  \
# SXS:BBH:0204                          0.841502  ...        NaN          NaN
# SXS:BBH:1131                          1.242480  ...        NaN          NaN
# SXS:BBH:1130                          1.242241  ...        NaN          NaN
# SXS:BBH:0623                          1.311154  ...        NaN          NaN
# SXS:BBH:3661                          1.381932  ...        NaN          NaN
# SXS:BBH:2299                          1.190024  ...        NaN          NaN
# SXS:BBH:2603                          1.190024  ...        NaN          NaN
# SXS:BBH:3913                          1.360753  ...        NaN          NaN
#
#                      date_link_earliest        date_postprocessing  \
# SXS:BBH:0204  2013-08-23 15:48:09-07:00  2019-04-14 19:48:30-07:00
# SXS:BBH:1131  2014-06-30 10:56:22-07:00  2019-04-20 18:22:40-07:00
# SXS:BBH:1130  2014-07-16 11:32:05-07:00  2019-04-20 18:22:40-07:00
# SXS:BBH:0623  2015-01-08 16:07:43-08:00  2019-04-20 18:22:40-07:00
# SXS:BBH:3661  2015-04-06 15:49:13-05:00  2019-04-18 10:17:19-07:00
# SXS:BBH:2299  2019-07-23 16:57:41-07:00  2019-08-23 11:56:35-07:00
# SXS:BBH:2603  2021-04-14 20:34:04-07:00  2021-05-25 13:15:50-07:00
# SXS:BBH:3913  2018-08-11 21:43:59-05:00  2019-05-09 19:46:53-07:00
#
#                       date_run_earliest            date_run_latest  \
# SXS:BBH:0204  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:1131  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:1130  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:0623  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3661  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:2299  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:2603  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
# SXS:BBH:3913  0001-01-01 00:00:00+00:00  0001-01-01 00:00:00+00:00
#
#               number_of_orbits superseded_by  \
# SXS:BBH:0204         88.369299           NaN
# SXS:BBH:1131         36.796011           NaN
# SXS:BBH:1130         36.775214           NaN
# SXS:BBH:0623         37.470458           NaN
# SXS:BBH:3661         41.006968           NaN
# SXS:BBH:2299         28.242072  SXS:BBH:2603
# SXS:BBH:2603         28.239081           NaN
# SXS:BBH:3913         40.585760           NaN
#
#                                         DOI_versions    keywords
# SXS:BBH:0204  [, v1.1, v1.2, v1.3, v1.4, v1.5, v2.0]          []
# SXS:BBH:1131        [, v1.2, v1.3, v1.4, v1.5, v2.0]          []
# SXS:BBH:1130        [, v1.2, v1.3, v1.4, v1.5, v2.0]          []
# SXS:BBH:0623        [, v1.2, v1.3, v1.4, v1.5, v2.0]          []
# SXS:BBH:3661                                [, v2.0]          []
# SXS:BBH:2299                                [, v2.0]  deprecated
# SXS:BBH:2603                                [, v2.0]          []
# SXS:BBH:3913                                [, v2.0]          []
#
# [8 rows x 59 columns]

# %% [markdown]
# ### Plotting
#
# Pandas also makes it easy to plot the various quantities.  For example, we can make a scatter plot of mass ratio versus $\chi_{\mathrm{eff}}$:

# %%
BHBH.plot("reference_mass_ratio", "reference_chi_eff", kind="scatter")

# pandas adds the column labels as axis labels, but we can make them look nicer
import matplotlib.pyplot as plt
plt.xlabel(r"Mass ratio")
plt.ylabel(r"$\chi_\mathrm{eff}$");

# %% [markdown]
# Or we can make histograms of the data:

# %%
BHBH["initial_ADM_linear_momentum_mag"].plot.hist(log=True)
plt.xlabel(r"Magnitude of ADM linear momentum");

# %% [markdown]
# We can even make corner plots:

# %%
import seaborn as sns

pp = sns.pairplot(
    BHBH[["reference_chi_eff", "reference_chi1_perp", "reference_chi2_perp", "reference_mass_ratio"]].dropna(),
    corner=True,
)
pp.y_vars = [r"$\chi_{\mathrm{eff}}$", r"$\chi_{\perp,1}$", r"$\chi_{\perp,2}$", r"$q$"]
pp.x_vars = pp.y_vars
pp._add_axis_labels()

# %% [markdown]
# The `simulations` object, especially when agumented with the `dataframe`, provides powerful methods for selecting the particular simulations we are interested in.  Once we have done so, we need to load and interact with the simulations.
#
# Continue with the [introduction to the `Simulation` objects](/tutorials/02-Simulation).
